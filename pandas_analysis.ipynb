# %%
import pandas as pd
df=pd.read_csv(r"C:\JupyterDemo\customer_shopping_behavior (1).csv")

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   str
#  3   Item Purchased          3900 non-null   str
#  4   Category                3900 non-null   str
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   str
#  7   Size                    3900 non-null   str
#  8   Color                   3900 non-null   str
#  9   Season                  3900 non-null   str
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   str
#  12  Shipping Type           3900 non-null   str
#  13  Discount Applied        3900 non-null   str
#  14  Promo Code Used         3900 non-null   str
# ...

# %%
df.describe(include='all')
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df['Review Rating']=df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')
df=df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='str')

# %%
#create a column age_group
labels=['young_adult','adult','middle_aged','senior']
df['age_group']=pd.qcut(df['age'],q=4,labels=labels)

# %%
df[['age','age_group']].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df[['age','age_group']].head(10)
#
# File C:\JupyterDemo\myenv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File C:\JupyterDemo\myenv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
# ...

# %%
# create column purchase_frequency_days
frequency_mapping={
     'Fortnightly':14,
     'Weekly':7,
     'Monthly':30,
     'Quarterly':90,
     'Bi-Weekly':14,
     'Annually':365,
     'Every 3 Months':90
 }
df['purchase_frequency_days']=df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['purchase_frequency_days','frequency_of_purchases']].head(10)
# Out:
#    purchase_frequency_days frequency_of_purchases
# 0                       14            Fortnightly
# 1                       14            Fortnightly
# 2                        7                 Weekly
# 3                        7                 Weekly
# 4                      365               Annually
# 5                        7                 Weekly
# 6                       90              Quarterly
# 7                        7                 Weekly
# 8                      365               Annually
# 9                       90              Quarterly

# %%
df[['discount_applied','promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes
# 5              Yes             Yes
# 6              Yes             Yes
# 7              Yes             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %%
(df['discount_applied']==df['promo_code_used']).all()
# Out:
# np.True_

# %%
df=df.drop('promo_code_used',axis=1)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'purchase_frequency_days'],
#       dtype='str')

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 14.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 12.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 11.7 MB/s  0:00:00
# ...
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# ...
#
#    ---------- ----------------------------- 1/4 [psycopg2-binary]
#    ---------- ----------------------------- 1/4 [psycopg2-binary]
#    ---------- ----------------------------- 1/4 [psycopg2-binary]
#    -------------------- ------------------- 2/4 [greenlet]
#    -------------------- ------------------- 2/4 [greenlet]
#    -------------------- ------------------- 2/4 [greenlet]
#    -------------------- ------------------- 2/4 [greenlet]
# ...

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\JupyterDemo\myenv\Scripts\python.exe -m pip install --upgrade pip

# %%
pip install pandas sqlalchemy mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\JupyterDemo\myenv\Scripts\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine
import urllib.parse  # We need this to handle the '@' in your password

# 1. Credentials
user = 'root'
# This "quotes" the password so the '@' doesn't break the connection
password = urllib.parse.quote_plus('Sweethome@1') 
host = '127.0.0.1'         
port = '3306'              
database = 'customer_shopping_behavior' 

# 2. Connection Bridge
engine = create_engine(f"mysql+mysqlconnector://{user}:{password}@{host}:{port}/{database}")

# 3. Create Sample Data
df = pd.DataFrame({
    'customer_id': [1, 2, 3],
    'product_category': ['Electronics', 'Home', 'Clothing'],
    'amount_spent': [150.00, 45.50, 80.25]
})

# 4. Push to MySQL    
df.to_sql('customer_test', con=engine, if_exists='replace', index=False)

print("Success! Check MySQL Workbench now.")
# Out:
# Success! Check MySQL Workbench now.

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:password@localhost/customer_shopping_behavior")
df.to_sql("customer_test", con=engine, if_exists="replace", index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from sqlalchemy import create_engine
# ----> 3 engine = create_engine("mysql+pymysql://root:password@localhost/customer_shopping_behavior")
#       4 df.to_sql("customer_test", con=engine, if_exists="replace", index=False)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File C:\JupyterDemo\myenv\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# ...

# %%
###

# %%
df.head()
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount  \
# 0            1   55   Male         Blouse  Clothing               53
# 1            2   19   Male        Sweater  Clothing               64
# 2            3   50   Male          Jeans  Clothing               73
# 3            4   21   Male        Sandals  Footwear               90
# 4            5   45   Male         Blouse  Clothing               49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    shipping_type discount_applied  previous_purchases payment_method  \
# ...

# %%
# This sends your ACTUAL cleaned data (with Age, Gender, etc.) to MySQL
# We will give it a new name 'customer_behavior_final' so it doesn't get mixed up
df.to_sql('customer_behavior_final', con=engine, if_exists='replace', index=False)

print("The REAL data is now uploaded!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # This sends your ACTUAL cleaned data (with Age, Gender, etc.) to MySQL
#       2 # We will give it a new name 'customer_behavior_final' so it doesn't get mixed up
# ----> 3 df.to_sql('customer_behavior_final', con=engine, if_exists='replace', index=False)
#       5 print("The REAL data is now uploaded!")
#
# NameError: name 'engine' is not defined

# %%
import pandas as pd
from sqlalchemy import create_engine
import urllib.parse  # We need this to handle the '@' in your password

# 1. Credentials
user = 'root'
# This "quotes" the password so the '@' doesn't break the connection
password = urllib.parse.quote_plus('Sweethome@1') 
host = '127.0.0.1'         
port = '3306'              
database = 'customer_shopping_behavior' 

# 2. Connection Bridge
engine = create_engine(f"mysql+mysqlconnector://{user}:{password}@{host}:{port}/{database}")

# 3. Create Sample Data
df = pd.DataFrame({
    'customer_id': [1, 2, 3],
    'product_category': ['Electronics', 'Home', 'Clothing'],
    'amount_spent': [150.00, 45.50, 80.25]
})

# 4. Push to MySQL    
df.to_sql('customer_test', con=engine, if_exists='replace', index=False)

print("Success! Check MySQL Workbench now.")
# Out:
# Success! Check MySQL Workbench now.

# %%
# Use the engine we already created
# We are naming this table 'customer_final_analysis' to avoid any confusion
df.to_sql('customer_final_analysis', con=engine, if_exists='replace', index=False)

print("The REAL cleaned data is now in MySQL under the name 'customer_final_analysis'!")
# Out:
# The REAL cleaned data is now in MySQL under the name 'customer_final_analysis'!

# %%
# We are naming this table something completely different to be 100% sure
df.to_sql('customer_shopping_full_data', con=engine, if_exists='replace', index=False)

print("The BIG dataset is now in MySQL!")
# Out:
# The BIG dataset is now in MySQL!

# %%
df.(head)
# Out:
#   Cell In[15], line 1
#     df.(head)
#        ^
# SyntaxError: invalid syntax

# %%
df.head()
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount  \
# 0            1   55   Male         Blouse  Clothing               53
# 1            2   19   Male        Sweater  Clothing               64
# 2            3   50   Male          Jeans  Clothing               73
# 3            4   21   Male        Sandals  Footwear               90
# 4            5   45   Male         Blouse  Clothing               49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    shipping_type discount_applied  previous_purchases payment_method  \
# ...

# %%
# This pushes your CURRENT big dataset to a brand new table name
# We use a new name to be 100% sure we are seeing the right thing
df.to_sql('final_shopping_data', con=engine, if_exists='replace', index=False)

print("The big table is now uploaded to MySQL as 'final_shopping_data'!")
# Out:
# The big table is now uploaded to MySQL as 'final_shopping_data'!
